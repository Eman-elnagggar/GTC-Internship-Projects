# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Data Source

# %% [markdown]
# [Data](https://www.kaggle.com/datasets/camnugent/california-housing-prices/data)

# %% [markdown]
# # Explore Data

# %%
pd.set_option('display.max_columns', None)

# %%
California_housing_prices=pd.read_csv("/content/drive/MyDrive/GTC_Internship/California housing prices /housing.csv")

# %%
California_housing_prices.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
California_housing_prices.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
California_housing_prices.shape
# Out:
# (20640, 10)

# %%
California_housing_prices.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ## NULLS

# %%
California_housing_prices.dropna(inplace=True)

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# ## change data types

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
def is_float(value):
  if value - int(value)>0:
    return 'yes'
  else:
    return "no"

# To ensure median_age of house with or without float values

median_age_is_float=California_housing_prices['housing_median_age'].apply(is_float)
median_age_is_float.value_counts()
# Out:
# housing_median_age
# no    20433
# Name: count, dtype: int64

# %%
California_housing_prices.shape
# Out:
# (20433, 10)

# %% [markdown]
# - change some floats to int

# %%
California_housing_prices[
    ['housing_median_age','total_rooms','total_bedrooms','population','households']
]=California_housing_prices[
    ['housing_median_age','total_rooms','total_bedrooms','population','households']].astype(int)

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  int64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
California_housing_prices['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
California_housing_prices['ocean_proximity']=California_housing_prices['ocean_proximity'].str.lower().str.strip()

# %%
California_housing_prices['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1h ocean     9034
# inland        6496
# near ocean    2628
# near bay      2270
# island           5
# Name: count, dtype: int64

# %%
California_housing_prices['ocean_proximity']=California_housing_prices['ocean_proximity'].astype('category')

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  int64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  category
# dtypes: category(1), float64(4), int64(5)
# memory usage: 1.6 MB

# %% [markdown]
# ## outliers

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  int64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  category
# dtypes: category(1), float64(4), int64(5)
# memory usage: 1.6 MB

# %%
California_housing_prices.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean        206864.413155
# std         115435.667099
# min          14999.000000
# 25%         119500.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %%
California_housing_prices.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# - total_rooms , tota_bedrooms , population , household are skewed

# %% [markdown]
# - fix distribution with log

# %%
California_housing_prices['total_bedrooms']=np.log(California_housing_prices['total_bedrooms']+1)
California_housing_prices['total_rooms']=np.log(California_housing_prices['total_rooms']+1)
California_housing_prices['population']=np.log(California_housing_prices['population']+1)
California_housing_prices['households']=np.log(California_housing_prices['households']+1)

# %%
California_housing_prices.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# - Data become more normal distribution

# %% [markdown]
# ## one hot encoding

# %%
# I'd like to try new way which with pandas

California_housing_prices=California_housing_prices.join(
    pd.get_dummies(California_housing_prices['ocean_proximity'], prefix='ocean')).drop(columns=['ocean_proximity'])

# %%
# see correlation

corr=California_housing_prices.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
# extract some new features
California_housing_prices['bedrooms_ratio']=California_housing_prices['total_bedrooms']/California_housing_prices['total_rooms']
California_housing_prices['household_rooms']=California_housing_prices['households']/California_housing_prices['total_rooms']

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_<1h ocean     20433 non-null  bool
#  10  ocean_inland        20433 non-null  bool
#  11  ocean_island        20433 non-null  bool
#  12  ocean_near bay      20433 non-null  bool
#  13  ocean_near ocean    20433 non-null  bool
#  14  bedrooms_ratio      20433 non-null  float64
#  15  household_rooms     20433 non-null  float64
# dtypes: bool(5), float64(10), int64(1)
# memory usage: 2.0 MB

# %%
# see correlation

corr=California_housing_prices.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
plt.show()

# %%
# do not show the upper triangle
# make the same shape of heat map with true value
bool_heat_map = np.zeros_like(corr, dtype=np.bool)
bool_heat_map[np.triu_indices_from(bool_heat_map)] = True
#change color map
color_map = sns.diverging_palette(215, 15, as_cmap=True)
plt.figure(figsize=(21,21))
sns.heatmap(corr, mask=bool_heat_map, cmap=color_map, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - learnt before high orrelation between variables i called multicolinearity and it should be droped

# %% [markdown]
# - population and total_rooms i highly correlated so I will get population to total room ratio and drop total_room

# %%
# extract some new features
California_housing_prices['population_room_ration']=California_housing_prices['population']/California_housing_prices['total_rooms']
California_housing_prices['population denisty']=California_housing_prices['population']/California_housing_prices['households']

# %%
# do not show the upper triangle
# make the same shape of heat map with true value
bool_heat_map = np.zeros_like(corr, dtype=np.bool)
bool_heat_map[np.triu_indices_from(bool_heat_map)] = True
#change color map
color_map = sns.diverging_palette(215, 15, as_cmap=True)
plt.figure(figsize=(21,21))
sns.heatmap(corr, mask=bool_heat_map, cmap=color_map, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - drop columns

# %%
California_housing_prices.drop(columns=['total_rooms','total_bedrooms','households','population'],inplace=True)

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   longitude               20433 non-null  float64
#  1   latitude                20433 non-null  float64
#  2   housing_median_age      20433 non-null  int64
#  3   median_income           20433 non-null  float64
#  4   median_house_value      20433 non-null  float64
#  5   ocean_<1h ocean         20433 non-null  bool
#  6   ocean_inland            20433 non-null  bool
#  7   ocean_island            20433 non-null  bool
#  8   ocean_near bay          20433 non-null  bool
#  9   ocean_near ocean        20433 non-null  bool
#  10  bedrooms_ratio          20433 non-null  float64
#  11  household_rooms         20433 non-null  float64
#  12  population_room_ration  20433 non-null  float64
#  13  population denisty      20433 non-null  float64
# dtypes: bool(5), float64(8), int64(1)
# memory usage: 1.7 MB

# %% [markdown]
# - drop longitude cause it high correlated to latitude

# %%
California_housing_prices.drop(columns=['longitude'],inplace=True)

# %%
California_housing_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   latitude                20433 non-null  float64
#  1   housing_median_age      20433 non-null  int64
#  2   median_income           20433 non-null  float64
#  3   median_house_value      20433 non-null  float64
#  4   ocean_<1h ocean         20433 non-null  bool
#  5   ocean_inland            20433 non-null  bool
#  6   ocean_island            20433 non-null  bool
#  7   ocean_near bay          20433 non-null  bool
#  8   ocean_near ocean        20433 non-null  bool
#  9   bedrooms_ratio          20433 non-null  float64
#  10  household_rooms         20433 non-null  float64
#  11  population_room_ration  20433 non-null  float64
#  12  population denisty      20433 non-null  float64
# dtypes: bool(5), float64(7), int64(1)
# memory usage: 1.5 MB

# %%
# see correlation

corr=California_housing_prices.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# - drop ocean_island cause model not interested in it

# %%
California_housing_prices.drop(columns=['ocean_island'],inplace=True)

# %%
# see correlation

corr=California_housing_prices.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# #Regression model

# %% [markdown]
# ## standerdization

# %%
y=California_housing_prices['median_house_value']
x=California_housing_prices.drop(columns=['median_house_value'],axis=1)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[ 1.05171726,  0.98216331,  2.34516291, ..., -1.71743929,
#         -1.24372927,  0.1917184 ],
#        [ 1.04235526, -0.60621017,  2.33263161, ...,  0.2676978 ,
#         -0.78365253, -0.98215519],
#        [ 1.03767426,  1.85576873,  1.78293943, ..., -1.81071595,
#         -1.2537898 ,  0.26564752],
#        ...,
#        [ 1.77727236, -0.92388486, -1.14317103, ...,  0.09061852,
#         -0.46336747, -0.53878799],
#        [ 1.77727236, -0.84446619, -1.05513604, ..., -0.12245745,
#         -0.7821621 , -0.68077016],
#        [ 1.74918635, -1.00330353, -0.78060586, ...,  0.20234722,
#         -0.16951301, -0.34413527]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,shuffle=True)

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_predict)

# %%
MSE
# Out:
# 4856489655.62961

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_predict)
r2
# Out:
# 0.6448683398332722

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.7773901503030036
